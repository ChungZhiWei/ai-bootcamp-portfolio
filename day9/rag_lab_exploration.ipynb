# %% [markdown]
# # 🔍 RAG Lab — Exploration Notebook
# **Day 9 · AI Application Development Bootcamp**
#
# This notebook walks you through the RAG pipeline step by step, letting you **see the output at every stage** before writing a full application.
#
# ---
#
# ### How to use this notebook
# - Run cells **in order** — later cells depend on earlier ones
# - Cells marked `# ✏️ YOUR TURN` have gaps for you to fill in
# - Cells marked `# 🔬 EXPERIMENT` invite you to change values and observe what happens
# - Write your reflections in the **📝 Reflection** markdown cells
#
# ### Sections at a glance
# | Part | Topic | Type |
# |---|---|---|
# | A | Guided pipeline walk-through | Run & read |
# | B | Parameter experiments | Fill in + reflect |
# | C | Open exploration (your own PDF, multi-query, scores) | Open |
# | D | **Web-Augmented RAG** — live web search as a retriever | Fill in |
# | E | **RAG Evaluation with RAGAS** *(optional)* — measure quality | Fill in |
#
# ### Before you start
# Make sure your virtual environment is active and `GROQ_API_KEY` is set:
# ```bash
# source .venv/bin/activate          # macOS/Linux
# # or
# .venv\Scripts\Activate.ps1        # Windows PowerShell
#
# export GROQ_API_KEY="gsk_..."
# ```
# Then launch Jupyter:
# ```bash

# %% [markdown]
# pip install jupyter  # if not already installed
# jupyter notebook
# ```

# %% [markdown]
# ---
# ## ⚙️ Setup — Install & Import

# %%
# Run this cell first — installs everything needed for the notebook
# (skip if you already ran pip install during the lecture setup)
import sys
# !{sys.executable} -m pip install -q \
    groq python-dotenv \
    langchain langchain-community langchain-chroma \
    langchain-huggingface chromadb pypdf sentence-transformers \
    langchain-groq \
    langchain-classic
print("✅ All packages ready")
# Out:
# ✅ All packages ready

# %%
import os
import shutil
import math
from pathlib import Path
from dotenv import load_dotenv

load_dotenv()  # reads GROQ_API_KEY from .env if present

# Quick check — will print ✅ if the key is available
api_key = os.getenv("GROQ_API_KEY")
if api_key:
    print(f"✅ GROQ_API_KEY found (starts with: {api_key[:8]}...)")
else:
    print("❌ GROQ_API_KEY not found — set it before continuing")
    print("   export GROQ_API_KEY='gsk_your_key_here'   # macOS/Linux")
    print("   $env:GROQ_API_KEY='gsk_your_key_here'    # Windows PS")
# Out:
# ✅ GROQ_API_KEY found (starts with: gsk_LFpE...)

# %% [markdown]
# ---
# ## 🅐 PART A — Guided Pipeline Walk-Through
#
# We will build the RAG pipeline one stage at a time and inspect the output at each step.
# Place any PDF you have in the same folder as this notebook and update `PDF_PATH` below.
# If you don't have one handy, you can save any Wikipedia article as a PDF from your browser.

# %% [markdown]
# ### A1 — Step 1: Load the PDF

# %%
from langchain_community.document_loaders import PyPDFLoader

# 📌 Change this to your PDF file name
PDF_PATH = "ChungZhiWeiResume.pdf"

loader = PyPDFLoader(PDF_PATH)
pages = loader.load()

print(f"📄 Pages loaded: {len(pages)}")
print()
print("--- Metadata of the first page ---")
print(pages[0].metadata)
print()
print("--- First 500 characters of page 1 ---")
print(pages[0].page_content[:500])
# Out:
# C:\Users\chung_3iinfgi\AppData\Local\Temp\ipykernel_16852\303380357.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# 📄 Pages loaded: 2
#
# --- Metadata of the first page ---
# {'producer': 'Skia/PDF m149 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'ChungZhiWeiResume.docx', 'source': 'ChungZhiWeiResume.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}
#
# --- First 500 characters of page 1 ---
# Chung  Zhi  Wei,  Timothy  (Mr.)
#
#
# +65
#
# 9190
#
# 1221
#
# |
#
# zhiweichung@gmail.com
#
# |
#
# Singapore
#
# |
#
# www.linkedin.com/in/zhi-wei-chung
#
# Game  Developer  with  4+  years  of  experience  building  and  deploying  Unity-based  multiplayer  applications  integrated
# with
#
# scalable
#
# backend
#
# systems.
#
# Experienced
#
# in
#
# real-time
#
# networking,
#
# WebSocket
#
# communication,
#
# Unity
#
# Gaming
#
# Services,
#
# and
#
# WebGL
#
# deployment.
#
# Strong
#
# background
#
# in
#
# game
#
# development,
#
# backend
#
# a

# %% [markdown]
# **What you should see:**
# - `pages` is a Python list — one `Document` object per page
# - Each Document has a `metadata` dict containing at minimum `page` (0-indexed) and `source` (the filename)
# - These metadata fields travel with each chunk all the way to ChromaDB and show up in your citations
#
# > **Why does the page number start at 0?** PyPDFLoader uses 0-based indexing internally. When displaying to users, add 1: `page + 1`.

# %% [markdown]
# ### A2 — Step 2: Split into Chunks

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=120,
    separators=["\n\n", "\n", ". ", " ", ""],
)
chunks = splitter.split_documents(pages)

print(f"✂️  Total chunks created: {len(chunks)}")
print(f"   Average chunk size: {sum(len(c.page_content) for c in chunks) // len(chunks)} chars")
print()
print("--- Sample: chunk #3 ---")
print(f"Metadata : {chunks[2].metadata}")
print(f"Length   : {len(chunks[2].page_content)} chars")
print(f"Content  : {chunks[2].page_content[:400]}")
# Out:
# ✂️  Total chunks created: 5
#    Average chunk size: 651 chars
#
# --- Sample: chunk #3 ---
# Metadata : {'producer': 'Skia/PDF m149 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'ChungZhiWeiResume.docx', 'source': 'ChungZhiWeiResume.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}
# Length   : 699 chars
# Content  : Game  Programmer  (Contract)  –  Singapore  University  of  Technology  and  Design
# Sep
#
# 2022
#
# –
#
# Mar
#
# 2025
#
# ●  Upgraded  two  existing  Unity  projects  by  implementing  multiplayer  functionality  with  the  first  project  using
# Websocket
#
# and
#
# Python
#
# and
#
# the
#
# second
#
# project
#
# using
#
# Unity
#
# Gaming
#
# Services.
#  ●  Developed  and  integrated  multiplayer  quiz  mechanics  int

# %% [markdown]
# **Notice:**
# - Chunk metadata still carries the original page number and source filename — inherited from the parent Document
# - Chunk size varies because `RecursiveCharacterTextSplitter` respects natural break points
# - `chunk_size=800` is the **maximum** — most chunks will be somewhat shorter

# %% [markdown]
# ### A3 — Step 3: Load the Embedding Model

# %%
from langchain_huggingface import HuggingFaceEmbeddings

print("Loading embedding model... (first run downloads ~80 MB)")
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
print("✅ Model loaded")

# Embed a single test sentence and inspect the vector
test_vector = embeddings.embed_query("What is the deadline for submission?")

print(f"\n🔢 Vector dimensions : {len(test_vector)}")
print(f"   First 8 values    : {[round(v, 4) for v in test_vector[:8]]}")
print(f"   Min value         : {min(test_vector):.4f}")
print(f"   Max value         : {max(test_vector):.4f}")
# Out:
# Loading embedding model... (first run downloads ~80 MB)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# ✅ Model loaded
#
# 🔢 Vector dimensions : 384
#    First 8 values    : [-0.0141, -0.0333, 0.0125, 0.0354, 0.0086, -0.0128, -0.1207, -0.0198]
#    Min value         : -0.1540
#    Max value         : 0.1974

# %% [markdown]
# **What you should see:**
# - Vector has exactly **384 dimensions** (that's the output size of MiniLM-L6)
# - Values are small floats, both positive and negative
# - These 384 numbers together encode the *meaning* of the sentence

# %% [markdown]
# ### A4 — Step 4: Demonstrate Cosine Similarity
#
# Before storing anything, let's see cosine similarity in action — the mechanism that powers retrieval.

# %%
def cosine_similarity(a, b):
    """Compute cosine similarity between two vectors."""
    dot   = sum(x * y for x, y in zip(a, b))
    mag_a = math.sqrt(sum(x ** 2 for x in a))
    mag_b = math.sqrt(sum(x ** 2 for x in b))
    return dot / (mag_a * mag_b)

sentences = {
    "query"    : "What is the late submission policy?",
    "similar"  : "Penalty for assignments handed in after the deadline",
    "related"  : "Students must attend all classes",
    "unrelated": "The best recipe for banana bread",
}

vectors   = {k: embeddings.embed_query(v) for k, v in sentences.items()}
query_vec = vectors["query"]

print(f'Base query: "{sentences["query"]}"\n')
for key in ["similar", "related", "unrelated"]:
    score = cosine_similarity(query_vec, vectors[key])
    bar   = "█" * int(score * 30)
    print(f"{score:.4f}  {bar}")
    print(f'         → "{sentences[key]}"')
    print()
# Out:
# Base query: "What is the late submission policy?"
#
# 0.4022  ████████████
#          → "Penalty for assignments handed in after the deadline"
#
# 0.0741  ██
#          → "Students must attend all classes"
#
# -0.0138
#          → "The best recipe for banana bread"

# %% [markdown]
# **Expected pattern:** `similar` should score highest (different words, same meaning), `related` moderate, `unrelated` very low.
# This is exactly what ChromaDB does for every query — computed across all stored chunk vectors simultaneously.

# %% [markdown]
# ### A5 — Step 5: Store in ChromaDB

# %%
from langchain_chroma import Chroma

CHROMA_DIR = "./chroma_lab_notebook"

if Path(CHROMA_DIR).exists():
    shutil.rmtree(CHROMA_DIR)
    print("🗑  Cleared old index")

print(f"Embedding {len(chunks)} chunks and storing in ChromaDB...")
vector_store = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory=CHROMA_DIR,
    collection_name="lab_exploration",
)

count = vector_store._collection.count()
print(f"✅ Done — {count} vectors stored in ChromaDB")
print(f"   Index saved to: {CHROMA_DIR}/")
# Out:
# 🗑  Cleared old index
# Embedding 5 chunks and storing in ChromaDB...
# ✅ Done — 5 vectors stored in ChromaDB
#    Index saved to: ./chroma_lab_notebook/

# %% [markdown]
# ### A6 — Step 6: Retrieve & Inspect Results

# %%
retriever = vector_store.as_retriever(search_kwargs={"k": 4})

QUESTION = "What are the main topics covered in this document?"

retrieved_docs = retriever.invoke(QUESTION)

print(f"❓ Question: {QUESTION}")
print(f"📋 Retrieved {len(retrieved_docs)} chunks:\n")

for i, doc in enumerate(retrieved_docs, 1):
    page = doc.metadata.get('page', '?')
    page_display = page + 1 if isinstance(page, int) else page
    print(f"--- Chunk {i} (page {page_display}) ---")
    print(doc.page_content[:300])
    print()
# Out:
# ❓ Question: What are the main topics covered in this document?
# 📋 Retrieved 4 chunks:
#
# --- Chunk 1 (page 2) ---
# ●  Designed  playtesting  plans  and  evaluation  questions.
# TECHNICAL  SKILLS
# Programming  Languages:  C#,  Python
# Game  Development:  Unity,  Unity  WebGL,  Unity  Gaming  Services
# Backend  Development:  Node.js,  MongoDB,  WebSocket
# Tools:  Github,  Microsoft  Office,  Google  Workspace
#
# --- Chunk 2 (page 1) ---
# Game  Programmer  (Contract)  –  Singapore  University  of  Technology  and  Design
# Sep
#
# 2022
#
# –
#
# Mar
#
# 2025
#
# ●  Upgraded  two  existing  Unity  projects  by  implementing  multiplayer  functionality  with  the  first  project  using
# Websocket
#
# and
#
# Python
#
# and
#
# the
#
# second
#
# project
#
#
#
# --- Chunk 3 (page 1) ---
# Bachelor  of  Arts  in  Game  Design  –  Digipen  Institute  of  Technology,  Singapore
# Aug
#
# 2015
#
# –
#
# Dec
#
# 2020
#
# Diploma  in  Interactive  Media  Informatics  –  Temasek  Polytechnic,  Singapore
# Apr
#
# 2010
#
# –
#
# Apr
#
# 2013
#
# PROFESSIONAL  EXPERIENCE
# Associate  Researcher  (Contract)  –  S
#
# --- Chunk 4 (page 1) ---
# Game  Programmer  (Contract)  –  Singapore  University  of  Technology  and  Design
# Mar
#
# 2021
#
# –
#
# Mar
#
# 2022
#
# ●  Developed  Unity-based  teaching  materials  for  undergraduate  game  design  modules.  ●  Designed  and  implemented  a  reinforcement  learning  AI  challenge  for  a  technical

# %% [markdown]
# **🔑 This is the most important debugging step in RAG.** Before looking at the LLM's answer, always inspect what the retriever found. If these chunks don't contain the answer, the LLM won't be able to answer correctly — no prompt tuning will fix a retrieval problem.

# %% [markdown]
# ### A7 — Step 7: Generate an Answer with Groq

# %%
from groq import Groq

SYSTEM_PROMPT = """You are a document-based AI assistant.
Answer ONLY using the retrieved context provided below.
For every fact, include the page number in parentheses, e.g. (page 2).
You can only use the information in the document to respond and if the 
information is not in the document reply with I could not find this 
information in the document."""
#If the answer is not in the context, say: I could not find that in the provided document."""

def format_context(docs):
    parts = []
    for i, doc in enumerate(docs, 1):
        page = doc.metadata.get('page', '?')
        page_display = page + 1 if isinstance(page, int) else page
        parts.append(f"[Source {i} | page {page_display}]\n{doc.page_content}")
    return "\n\n---\n\n".join(parts)

def ask_rag(question, retriever, model="llama-3.1-8b-instant", temperature=0.2):
    """Full RAG loop: retrieve → build prompt → generate → return (answer, docs)."""
    docs    = retriever.invoke(question)
    context = format_context(docs)
    prompt  = f"""Question: {question}

Retrieved context:
{context}

Answer using ONLY the context above. Include page references."""

    client   = Groq(api_key=os.getenv("GROQ_API_KEY"))
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user",   "content": prompt},
        ],
        temperature=temperature,
    )
    return response.choices[0].message.content, docs

answer, retrieved = ask_rag(QUESTION, retriever)

print(f"❓ Question: {QUESTION}")
print()
print("📋 Retrieved chunks:")
for i, doc in enumerate(retrieved, 1):
    page = doc.metadata.get('page', '?')
    page_display = page + 1 if isinstance(page, int) else page
    print(f"  [{i}] page {page_display}: {doc.page_content[:80]}...")
print()
print("🤖 Answer:")
print(answer)
# Out:
# ❓ Question: What are the main topics covered in this document?
#
# 📋 Retrieved chunks:
#   [1] page 2: ●  Designed  playtesting  plans  and  evaluation  questions.
# TECHNICAL  SKILLS...
#   [2] page 1: Game  Programmer  (Contract)  –  Singapore  University  of  Technology  and  Des...
#   [3] page 1: Bachelor  of  Arts  in  Game  Design  –  Digipen  Institute  of  Technology,  Si...
#   [4] page 1: Game  Programmer  (Contract)  –  Singapore  University  of  Technology  and  Des...
#
# 🤖 Answer:
# The main topics covered in this document are:
#
# 1. Technical skills (page 2): The document lists various programming languages, game development tools, and backend development technologies that the individual is proficient in.
# 2. Professional experience (pages 1-4): The document details the individual's work experience, including their roles, job titles, and the duration of their employment at various institutions.
# 3. Education (page 3): The document mentions the individual's educational background, including their degree in Game Design from Digipen Institute of Technology and a Diploma in Interactive Media Informatics from Temasek Polytechnic.
# 4. Projects and achievements (pages 1-4): The document highlights various projects and achievements, such as upgrading Unity projects, developing multiplayer quiz mechanics, conducting penetration testing, and designing and deploying a Node.js + MongoDB backend server.
#
# These topics provide an overview of the individual's technical skills, professional experience, education, and achievements in the field of game development.

# %% [markdown]
# ---
# ## 🅑 PART B — Experiments
#
# Now you modify parameters and observe how they affect retrieval quality. **This is the core skill of RAG engineering.**

# %% [markdown]
# ### B1 — ✏️ YOUR TURN: Chunk Size Experiment
#
# Re-index your document with **three different chunk sizes** and compare how many chunks are created and how the retrieved text looks.
# Fill in the `build_index()` function below — it should work for all three sizes.

# %%
def build_index(pages, chunk_size, chunk_overlap, chroma_dir):
    """
    Build a ChromaDB index from pages with the given chunking parameters.
    Returns (vector_store, chunks)
    """
    # ✏️ YOUR TURN: create the splitter
    # Hint: RecursiveCharacterTextSplitter(chunk_size=..., chunk_overlap=..., separators=[...])
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        separators=["\n\n", "\n", ". ", " ", ""],
    )

    # ✏️ YOUR TURN: split the pages into chunks
    chunks = splitter.split_documents(pages)
    
    if Path(chroma_dir).exists():
        shutil.rmtree(chroma_dir)

    # ✏️ YOUR TURN: create the ChromaDB vector store
    # Hint: Chroma.from_documents(documents=chunks, embedding=embeddings, persist_directory=chroma_dir, collection_name="exp")
    store = Chroma.from_documents(
        documents=chunks,
        embedding=embeddings,
        persist_directory=chroma_dir,
        collection_name="exp",
    )

    return store, chunks


# ── Run for three chunk sizes ─────────────────────────────────────────────────
test_question = "What are the main topics covered in this document?"
results = {}

for size in [300, 800, 1500]:
    overlap = int(size * 0.15)
    store, cks = build_index(pages, size, overlap, f"./chroma_exp_{size}")
    ret  = store.as_retriever(search_kwargs={"k": 3})
    docs = ret.invoke(test_question)
    results[size] = {"chunk_count": len(cks), "retrieved": docs}
    print(f"chunk_size={size:>4}: {len(cks):>4} chunks total | retrieved {len(docs)} docs")

print("\n✅ Experiment complete — run the next cell to compare retrieved text")
# Out:
# chunk_size= 300:   13 chunks total | retrieved 3 docs
# chunk_size= 800:    5 chunks total | retrieved 3 docs
# chunk_size=1500:    3 chunks total | retrieved 3 docs
#
# ✅ Experiment complete — run the next cell to compare retrieved text

# %%
# Inspect retrieved chunks for each size side-by-side
for size, data in results.items():
    print(f"\n{'='*60}")
    print(f"  chunk_size = {size}  ({data['chunk_count']} total chunks)")
    print(f"{'='*60}")
    for i, doc in enumerate(data["retrieved"], 1):
        page = doc.metadata.get('page', '?')
        page_display = page + 1 if isinstance(page, int) else page
        print(f"  [{i}] page {page_display} | {len(doc.page_content)} chars")
        print(f"      {doc.page_content[:200]}")
        print()
# Out:
# ============================================================
#   chunk_size = 300  (13 total chunks)
# ============================================================
#   [1] page 2 | 243 chars
#       ●  Designed  playtesting  plans  and  evaluation  questions.
# TECHNICAL  SKILLS
# Programming  Languages:  C#,  Python
# Game  Development:  Unity,  Unity  WebGL,  Unity  Gaming  Services
# Backend
#
#   [2] page 1 | 256 chars
#       environments.
#
# Passionate
#
# about
#
# clean
#
# architecture,
#
# performance
#
# optimization,
#
# and
#
# scalable
#
# system
#
# design.
#
# EDUCATION
# Bachelor  of  Arts  in  Game  Design  –  Digipen  Institute
#
#   [3] page 1 | 95 chars
#       .  ●  Created  multiple  Unity  prototypes  to  test  gameplay  concepts  and  research  ideas.
#
#
# ============================================================
#   chunk_size = 800  (5 total chunks)
# ============================================================
#   [1] page 2 | 361 chars
#       ●  Designed  playtesting  plans  and  evaluation  questions.
# TECHNICAL  SKILLS
# Programming  Languages:  C#,  Python
# Game  Development:  Unity,  Unity  WebGL,  Unity  Gaming  Services
# Backend
#
#   [2] page 1 | 699 chars
#       Game  Programmer  (Contract)  –  Singapore  University  of  Technology  and  Design
# Sep
#
# 2022
#
# –
#
# Mar
#
# 2025
#
# ●  Upgraded  two  existing  Unity  projects  by  implementing  multiplayer  function
#
#   [3] page 1 | 727 chars
#       Bachelor  of  Arts  in  Game  Design  –  Digipen  Institute  of  Technology,  Singapore
# Aug
#
# 2015
#
# –
#
# Dec
#
# 2020
#
# Diploma  in  Interactive  Media  Informatics  –  Temasek  Polytechnic,  Singapor
#
#
# ============================================================
#   chunk_size = 1500  (3 total chunks)
# ============================================================
#   [1] page 2 | 361 chars
#       ●  Designed  playtesting  plans  and  evaluation  questions.
# TECHNICAL  SKILLS
# Programming  Languages:  C#,  Python
# Game  Development:  Unity,  Unity  WebGL,  Unity  Gaming  Services
# Backend
#
#   [2] page 1 | 1271 chars
#       Game  Programmer  (Contract)  –  Singapore  University  of  Technology  and  Design
# Sep
#
# 2022
#
# –
#
# Mar
#
# 2025
#
# ●  Upgraded  two  existing  Unity  projects  by  implementing  multiplayer  function
#
#   [3] page 1 | 1397 chars
#       Chung  Zhi  Wei,  Timothy  (Mr.)
#
#
# +65
#
# 9190
#
# 1221
#
# |
#
# zhiweichung@gmail.com
#
# |
#
# Singapore
#
# |
#
# www.linkedin.com/in/zhi-wei-chung
#
# Game  Developer  with  4+  years  of  experience  building

# %% [markdown]
# ### 📝 Reflection B1
#
# 1. **How did chunk count change** as chunk_size increased from 300 → 800 → 1500?
#
#    *Your answer:* chunk count decreases as chunk_size increases.
#
# 2. **Which chunk size returned the most useful context** for your question? Why?
#
#    *Your answer:* chunk size 800 return the most useful context because I upload resume and my skills list are getting chopped.
#
# 3. **With chunk_size=300**, did any retrieved chunk seem too short to be useful on its own?
#
#    *Your answer:* Yes. some chunks like my skills list is incomplete because it got chopped.
#
# 4. **With chunk_size=1500**, did the retrieved chunk contain irrelevant sentences alongside the relevant ones?
#
#    *Your answer:* Yes. The retrieved chunk managed to get my work experience but it also stretch to my contact information and stopped halfway on my background.

# %% [markdown]
# ### B2 — ✏️ YOUR TURN: The k Parameter Experiment
#
# Using a `chunk_size=800` index, compare what happens when you retrieve **k=1**, **k=4**, and **k=10** chunks.

# %%
store_800, _ = build_index(pages, 800, 120, "./chroma_k_exp")

# ✏️ YOUR TURN: pick a question relevant to YOUR document
question = "What is my background?"  # Replace with something meaningful for your PDF

print(f"Question: {question}\n")

for k in [1, 4, 10]:
    # ✏️ YOUR TURN: create a retriever with this k value and retrieve docs
    # Hint: store_800.as_retriever(search_kwargs={"k": k})
    retriever_k = store_800.as_retriever(search_kwargs={"k": k})  # YOUR CODE HERE
    docs_k      = retriever_k.invoke(question)  # YOUR CODE HERE

    total_chars = sum(len(d.page_content) for d in docs_k)
    pages_found = [d.metadata.get('page', '?') for d in docs_k]
    print(f"k={k:2d} → {len(docs_k)} chunks | ~{total_chars} chars of context | pages: {pages_found}")
# Out:
# Question: What is my background?
#
# k= 1 → 1 chunks | ~727 chars of context | pages: [0]
# k= 4 → 4 chunks | ~2898 chars of context | pages: [0, 0, 0, 0]
# k=10 → 5 chunks | ~3259 chars of context | pages: [0, 0, 0, 0, 1]

# %%
# Compare the ANSWERS generated with k=1 vs k=4 vs k=10
for k in [1, 4, 10]:
    ret_k    = store_800.as_retriever(search_kwargs={"k": k})
    ans_k, _ = ask_rag(question, ret_k)
    print(f"\n{'─'*60}")
    print(f"  k = {k}")
    print(f"{'─'*60}")
    print(ans_k)
# Out:
# ────────────────────────────────────────────────────────────
#   k = 1
# ────────────────────────────────────────────────────────────
# Based on the retrieved context, your background is in Game Design and Interactive Media Informatics.
#
# You hold a Bachelor of Arts in Game Design from Digipen Institute of Technology, Singapore (page 1), which you completed from Aug 2015 to Dec 2020.
#
# Additionally, you have a Diploma in Interactive Media Informatics from Temasek Polytechnic, Singapore (page 1), which you completed from Apr 2010 to Apr 2013.
#
# Your professional experience includes working as an Associate Researcher (Contract) and a Game Programmer (Contract) at the Singapore University of Technology and Design, but your background is more focused on Game Design and Interactive Media Informatics.
#
# ────────────────────────────────────────────────────────────
#   k = 4
# ────────────────────────────────────────────────────────────
# Based on the retrieved context, your background is in Game Design and Development.
#
# You hold a Bachelor of Arts in Game Design from Digipen Institute of Technology, Singapore (Aug 2015 - Dec 2020) (Source 1, page 1 and Source 2, page 1).
#
# You also have a Diploma in Interactive Media Informatics from Temasek Polytechnic, Singapore (Apr 2010 - Apr 2013) (Source 1, page 1).
#
# Your professional experience includes various roles such as Associate Researcher, Game Programmer, and Student Researcher, all of which are related to game development and programming (Source 1, page 1 and Source 3, page 1).
#
# You have experience with Unity, Node.js, MongoDB, WebGL, and other technologies relevant to game development (Source 1, page 1 and Source 2, page 1).
#
# Your LinkedIn profile describes you as a Game Developer with 4+ years of experience building and deploying Unity-based multiplayer applications (Source 2, page 1).
#
# ────────────────────────────────────────────────────────────
#   k = 10
# ────────────────────────────────────────────────────────────
# Based on the retrieved context, your background is in game development and programming.
#
# You have a Bachelor of Arts in Game Design from Digipen Institute of Technology, Singapore (Aug 2015 - Dec 2020) (Source 1, page 1 and Source 2, page 1).
#
# You have experience as a Game Programmer (Contract) at Singapore University of Technology and Design, with multiple stints from Sep 2022 - Mar 2025 (Source 4, page 1), Mar 2021 - Mar 2022 (Source 3, page 1 and Source 4, page 1), and Sep 2022 - Mar 2025 (Source 1, page 1).
#
# You have also worked as an Associate Researcher (Contract) at Singapore University of Technology and Design from Apr 2025 - Mar 2026 (Source 1, page 1).
#
# Your technical skills include programming languages such as C# and Python, game development using Unity, Unity WebGL, and Unity Gaming Services, and backend development using Node.js, MongoDB, and WebSocket (Source 5, page 2).
#
# You are also proficient in tools such as Github, Microsoft Office, and Google Workspace (Source 5, page 2).
#
# Your languages include English (fluent) and Chinese (conversational) (Source 5, page 2).

# %% [markdown]
# ### 📝 Reflection B2
#
# 1. **k=1 vs k=4:** Did increasing k improve the answer? In what way?
#
#    *Your answer:* Increasing k does help make the output not so strict with copying what was written as my background.
#
# 2. **k=10:** Better or worse than k=4? Any sign of context dilution?
#
#    *Your answer:* k=10 is worse than k=4 because k=4 would list my background while k-10 would make generic statements about my background.
#
# 3. **If you had to pick one k value**, which would you choose and why?
#
#    *Your answer:* I would choose k=4 because it gives me my background information which is written in the document and not generic statements or just copy my background statement.

# %% [markdown]
# ### B3 — ✏️ YOUR TURN: Temperature Experiment

# %%
retriever_b3 = store_800.as_retriever(search_kwargs={"k": 4})
question_b3  = question  # reuse your question from B2

for temp in [0.0, 0.5, 1.0]:
    # ✏️ YOUR TURN: call ask_rag with the current temperature
    # Hint: ask_rag(question, retriever, temperature=temp)
    answer_t, _ = ask_rag(question, retriever, temperature=temp)  # YOUR CODE HERE

    print(f"\n{'─'*60}")
    print(f"  temperature = {temp}")
    print(f"{'─'*60}")
    print(answer_t)
# Out:
# ────────────────────────────────────────────────────────────
#   temperature = 0.0
# ────────────────────────────────────────────────────────────
# Based on the retrieved context, your background is in Game Development, specifically in Unity-based applications, with a strong background in:
#
# - Game development (Source 2, page 1)
# - Backend architecture (Source 2, page 1)
# - Research environments (Source 2, page 1)
# - Real-time networking (Source 2, page 1)
# - WebSocket communication (Source 2, page 1)
# - Unity Gaming Services (Source 2, page 1)
# - WebGL deployment (Source 2, page 1)
# - Clean architecture (Source 2, page 1)
# - Performance optimization (Source 2, page 1)
# - Scalable system design (Source 2, page 1)
#
# You have also worked as a Game Programmer (Contract) at Singapore University of Technology and Design from Sep 2022 to Mar 2025 (Source 1, page 1 and Source 4, page 1), and have experience in designing and deploying Unity-based multiplayer applications (Source 1, page 1 and Source 2, page 1).
#
# Additionally, you have a Bachelor of Arts in Game Design from Digipen Institute of Technology, Singapore (Source 1, page 1 and Source 2, page 1), and a Diploma in Interactive Media Informatics from Temasek Polytechnic, Singapore (Source 1, page 1).
#
# ────────────────────────────────────────────────────────────
#   temperature = 0.5
# ────────────────────────────────────────────────────────────
# Based on the retrieved context, it appears that you have a background in Game Design and Development. Here are some details:
#
# - You hold a Bachelor of Arts in Game Design from Digipen Institute of Technology, Singapore (Aug 2015 - Dec 2020) (Source 1, page 1; Source 2, page 1).
# - You also hold a Diploma in Interactive Media Informatics from Temasek Polytechnic, Singapore (Apr 2010 - Apr 2013) (Source 1, page 1).
# - Your professional experience includes roles such as Associate Researcher (Contract) and Game Programmer (Contract) at the Singapore University of Technology and Design, where you have gained experience in building and deploying Unity-based multiplayer applications, real-time networking, and scalable backend systems (Source 1, page 1).
# - You have also worked on various projects, including developing Unity-based teaching materials, designing and implementing a reinforcement learning AI challenge, and creating multiple Unity prototypes (Source 3, page 1).
# - Additionally, you have experience in penetration testing using Burp Suite (Source 4, page 1).
#
# Overall, your background suggests that you have a strong foundation in game development, backend architecture, and research environments, with a passion for clean architecture, performance optimization, and scalable system design (Source 2, page 1).
#
# ────────────────────────────────────────────────────────────
#   temperature = 1.0
# ────────────────────────────────────────────────────────────
# Based on the provided context, your background appears to be (page 1):
#
# - A Game Developer with 4+ years of experience in building and deploying Unity-based multiplayer applications integrated with scalable backend systems.
# - Strong background in game development, backend architecture, and research environments.
# - Experienced in real-time networking, WebSocket communication, Unity Gaming Services, and WebGL deployment.
#
# Your educational background shows that you have (page 2, Source 1):
#
# - A Bachelor of Arts in Game Design from Digipen Institute of Technology in Singapore.
# - A Diploma in Interactive Media Informatics from Temasek Polytechnic, Singapore.

# %% [markdown]
# ### 📝 Reflection B3
#
# 1. **temperature=0.0 vs 1.0:** How did the answer style differ? Was it more or less consistent on re-run?
#
#    *Your answer:* temperature=0 gives me the same list while temperature=1 gives me a different list with every re-run.
#
# 2. **For a factual document Q&A system**, which temperature range would you recommend and why?
#
#    *Your answer:* temperature=0. This is because it needs to give the same answer for factual answers.

# %% [markdown]
# ### B4 — 🔬 EXPERIMENT: Ask an Out-of-Scope Question

# %%
retriever_b4   = store_800.as_retriever(search_kwargs={"k": 4})
out_of_scope_q = "What is the current price of Bitcoin in Singapore dollars?"

answer_oos, docs_oos = ask_rag(out_of_scope_q, retriever_b4)

print(f"❓ Question: {out_of_scope_q}")
print()
print("📋 What the retriever found (likely unrelated):")
for doc in docs_oos:
    page = doc.metadata.get('page', '?')
    page_display = page + 1 if isinstance(page, int) else page
    print(f"  page {page_display}: {doc.page_content[:100]}...")
print()
print("🤖 Answer:")
print(answer_oos)
# Out:
# ❓ Question: What is the current price of Bitcoin in Singapore dollars?
#
# 📋 What the retriever found (likely unrelated):
#   page 1: Game  Programmer  (Contract)  –  Singapore  University  of  Technology  and  Design
# Sep
#
# 2022
#
# –...
#   page 1: Chung  Zhi  Wei,  Timothy  (Mr.)
#
#
# +65
#
# 9190
#
# 1221
#
# |
#
# zhiweichung@gmail.com
#
# |
#
# Singapore
#  ...
#   page 1: Bachelor  of  Arts  in  Game  Design  –  Digipen  Institute  of  Technology,  Singapore
# Aug
#
# 2015...
#   page 2: ●  Designed  playtesting  plans  and  evaluation  questions.
# TECHNICAL  SKILLS
# Programming  Lang...
#
# 🤖 Answer:
# I could not find this information in the document.

# %% [markdown]
# ### 📝 Reflection B4
#
# 1. Did the model correctly refuse, or did it hallucinate using irrelevant context?
#
#    *Your answer:* Yes. The model answer with "it could not find it in the provided document".
#
# 2. If it hallucinated: what in `SYSTEM_PROMPT` could you change to make refusal more reliable?
#
#    *Your answer:* I would write that it could only use the information in the document to respond and if the information is not in the document reply with "I could not find this information in the document.".
#
# 3. Modify `SYSTEM_PROMPT` in cell A7 to make refusal more explicit, re-run, and report what changed:
#
#    *Your answer:* It responded with I could not find this information in the document.

# %% [markdown]
# ---
# ## 🅒 PART C — Open Exploration

# %% [markdown]
# ### C1 — ✏️ YOUR TURN: Test Your Own PDF

# %%
import gc

# ✏️ YOUR TURN: load and index your own PDF, then ask 3 questions
MY_PDF = "ChungZhiWeiResume.pdf"

# YOUR CODE HERE — follow the same steps as Parts A1 → A6
# Step 1: load   →  PyPDFLoader(MY_PDF).load()
loader = PyPDFLoader(MY_PDF)
pages = loader.load()

# Step 2: chunk  →  build_index() from B1
store_800, c = build_index(pages, 800, 120, "./chroma_lab_C1")
retriever = store_800.as_retriever(search_kwargs={"k": 3})
# Step 3: ask 3 questions with ask_rag()
answer0, retrieved0 = ask_rag("What is my role?", retriever)
answer1, retrieved1 = ask_rag("What is my background?", retriever)
answer2, retrieved2 = ask_rag("How long have I worked?", retriever)

print(f"What is my Role?\n{answer0}")
print(f"What is my background?\n{answer1}")
print(f"How long have I worked?\n{answer2}")
# Out:
# What is my Role?
# Based on the retrieved context, your role is a Game Programmer (Contract) at Singapore University of Technology and Design, with a previous role as an Associate at EY. (Source 1, page 1)
# What is my background?
# Based on the retrieved context, your background is in Game Development, specifically in Unity-based applications, backend architecture, and research environments.
#
# You have a Bachelor of Arts in Game Design from Digipen Institute of Technology, Singapore (Aug 2015 - Dec 2020) (Source 1, page 1; Source 2, page 1).
#
# You have experience as a Game Programmer (Contract) at Singapore University of Technology and Design, where you designed and deployed a Node.js + MongoDB backend server to support a browser-hosted Unity game (Apr 2025 - Mar 2026) (Source 1, page 1).
#
# You have also worked as a Student Researcher (Intern) at Singapore Institute of Technology, where you collected and processed building data using point cloud technology and modeled 3D structures and implemented sound for VR using Unity and Maya (Apr 2020 - Dec 2020) (Source 3, page 1).
#
# Additionally, you have a strong background in real-time networking, WebSocket communication, Unity Gaming Services, and WebGL deployment (Source 2, page 1).
# How long have I worked?
# Based on the provided context, it appears that you have worked in multiple positions, but I will try to determine how long you have worked in total.
#
# From the context, we can see that you have worked in the following positions:
#
# 1. Game Programmer (Contract) at Singapore University of Technology and Design (Source 1, page 1):
#    - Mar 2021 - Mar 2022 (Source 3, page 1)
#    - Sep 2022 - Mar 2025 (Source 1, page 1 and Source 2, page 1)
#    - Total duration: approximately 3 years and 4 months (Mar 2021 - Mar 2025)
#
# 2. Associate, Consulting at EY (Source 1, page 1):
#    - May 2022 - Sep 2022 (Source 1, page 1)
#    - Duration: approximately 5 months
#
# 3. Associate Researcher (Contract) at Singapore University of Technology and Design (Source 2, page 1):
#    - Apr 2025 - Mar 2026 (Source 2, page 1)
#    - Duration: approximately 11 months
#
# 4. Student Researcher (Intern) at Singapore Institute of Technology (Source 3, page 1):
#    - Apr 2020 - Dec 2020 (Source 3, page 1)
#    - Duration: approximately 9 months
#
# 5. Diploma in Interactive Media Informatics at Temasek Polytechnic, Singapore (Source 2, page 1):
#    - Apr 2010 - Apr 2013 (Source 2, page 1)
#    - Duration: approximately 3 years
#
# 6. Bachelor of Arts in Game Design at Digipen Institute of Technology, Singapore (Source 2, page 1):
#    - Aug 2015 - Dec 2020 (Source 2, page 1)
#    - Duration: approximately 5 years and 4 months
#
# Adding up the durations of all these positions, we get:
# - 3 years and 4 months (Game Programmer) + 5 months (Associate, Consulting) + 11 months (Associate Researcher) + 9 months (Student Researcher) + 3 years (Diploma) + 5 years and 4 months (Bachelor) = approximately 17 years and 7 months.
#
# However, this calculation includes your education and internship periods, which may not be considered as "work" in the traditional sense. If we only consider your professional work experience, the total duration would be approximately 4 years and 9 months (3 years and 4 months as Game Programmer + 5 months as Associate, Consulting + 11 months as Associate Researcher).

# %% [markdown]
# ### 📝 Reflection C1
#
# | Question | Retrieval correct? | Answer quality (1–5) | Notes |
# |---|---|---|---|
# | Q1: What is my role? | Yes | 4 | The adding of contract in my job role was unnecessary. |
# | Q2: What is my background? | Yes | 3 | It list my job roles but nothing on what I do. |
# | Q3: How long have I worked? | Yes | 4 | It attempted to calculate my job years worked so its good. |
#
# **Best chunk_size and k for your document?** 800/3

# %% [markdown]
# ### C2 — 🔬 EXPERIMENT: Multi-Query Retrieval

# %%
from langchain_classic.retrievers.multi_query import MultiQueryRetriever
from langchain_groq import ChatGroq

llm = ChatGroq(
    model_name="llama-3.1-8b-instant",
    temperature=0,
    groq_api_key=os.getenv("GROQ_API_KEY"),
)

base_retriever  = store_800.as_retriever(search_kwargs={"k": 4})
multi_retriever = MultiQueryRetriever.from_llm(retriever=base_retriever, llm=llm)

test_q        = question  # reuse your question from B2
docs_standard = base_retriever.invoke(test_q)
docs_multi    = multi_retriever.invoke(test_q)

print(f"Standard retrieval : {len(docs_standard)} chunks")
print(f"Multi-query        : {len(docs_multi)} chunks (after dedup)")

standard_texts = {d.page_content for d in docs_standard}
extra_chunks   = [d for d in docs_multi if d.page_content not in standard_texts]
print(f"\nExtra chunks found ONLY by multi-query: {len(extra_chunks)}")
for doc in extra_chunks:
    page = doc.metadata.get('page', '?')
    page_display = page + 1 if isinstance(page, int) else page
    print(f"  [page {page_display}] {doc.page_content[:150]}")
# Out:
# Standard retrieval : 4 chunks
# Multi-query        : 5 chunks (after dedup)
#
# Extra chunks found ONLY by multi-query: 1
#   [page 2] ●  Designed  playtesting  plans  and  evaluation  questions.
# TECHNICAL  SKILLS
# Programming  Languages:  C#,  Python
# Game  Development:  Unity,

# %% [markdown]
# ### C3 — 🔬 EXPERIMENT: Retrieval with Similarity Scores

# %%
results_with_scores = vector_store.similarity_search_with_score(question, k=6)

print(f"Question: {question}\n")
print(f"{'Similarity':>10}  {'Page':>5}  Content preview")
print("-" * 72)
for doc, score in results_with_scores:
    page = doc.metadata.get('page', '?')
    page_display = page + 1 if isinstance(page, int) else page
    similarity   = 1 / (1 + score)  # convert L2 distance to rough similarity
    print(f"{similarity:>10.4f}  {str(page_display):>5}  {doc.page_content[:60]}...")
# Out:
# Question: What is my background?
#
# Similarity   Page  Content preview
# ------------------------------------------------------------------------
#     0.3834      1  Bachelor  of  Arts  in  Game  Design  –  Digipen  Institute ...
#     0.3770      1  Chung  Zhi  Wei,  Timothy  (Mr.)
#
#
# +65
#
# 9190
#
# 1221
#
# |
#  ...
#     0.3607      1  Game  Programmer  (Contract)  –  Singapore  University  of  ...
#     0.3573      1  Game  Programmer  (Contract)  –  Singapore  University  of  ...
#     0.3410      2  ●  Designed  playtesting  plans  and  evaluation  questions....

# %% [markdown]
# ### 📝 Reflection C — Overall
#
# 1. Is there a clear similarity score gap between the most and least relevant chunks?
#
#    No there was not any similarity score gap between the chunks.
#
# 2. **Two most important RAG parameters to tune** for a new document collection?
#
#    The document chunk size and the k parameter.
#
# 3. **Which mini-project did you choose, and why?** What do you expect to be hardest?
#
#    *Your answer:*

# %% [markdown]
# ---
# ## 🌐 PART D — Web-Augmented RAG
#
# ### What is Web-Augmented RAG?
#
# So far, every answer has been grounded in a **local PDF** that you indexed yourself. But what if the user asks something that is not in any of your documents — for example, a current event, a recent product release, or a live regulation?
#
# **Web-Augmented RAG** solves this by replacing (or combining) the vector-store retriever with a **live web search**. Instead of fetching chunks from ChromaDB, the system searches the web in real time, retrieves the top results, and uses those as the LLM's context.
#
# ```
# Standard RAG:          Question → ChromaDB → chunks → LLM → answer
# Web-Augmented RAG:     Question → Web search → live results → LLM → answer
# Combined (best):       Question → ChromaDB + Web search → merge → LLM → answer
# ```
#
# ### Tool we use: Tavily Search
#
# **Tavily** is a search API designed specifically for LLM applications. It returns clean, structured, LLM-friendly text from web results — not raw HTML. LangChain has a native `TavilySearchResults` integration.
#
# **Free tier:** 1,000 searches/month — more than enough for this lab.
# **Sign up:** https://tavily.com → get your API key in 30 seconds.
#
# ### D0 — Install & Set Your Tavily Key

# %%
# Install the Tavily integration
import sys
# !{sys.executable} -m pip install -q tavily-python langchain-community
print("✅ Tavily installed")
# Out:
# ✅ Tavily installed

# %%
# Set your Tavily API key
# Get it from: https://app.tavily.com/home  (free, takes ~30 seconds)
#
# Option A — add to your .env file:    TAVILY_API_KEY=tvly-...
# Option B — set it here for this session only (do not commit this notebook with the key visible):
#
# import os
# os.environ["TAVILY_API_KEY"] = "tvly-your-key-here"
load_dotenv()

tavily_key = os.getenv("TAVILY_API_KEY") #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
if tavily_key:
    print(f"✅ TAVILY_API_KEY found (starts with: {tavily_key[:8]}...)")
else:
    print("❌ TAVILY_API_KEY not set.")
    print("   Get a free key at https://app.tavily.com/home")
    print("   Then add TAVILY_API_KEY=tvly-... to your .env file and re-run this cell.")
# Out:
# ✅ TAVILY_API_KEY found (starts with: tvly-dev...)

# %% [markdown]
# ### D1 — Guided: Web Search as a Retriever
#
# Here we use `TavilySearchResults` as a drop-in retriever. The API returns a list of result objects, each with `content` (the page text) and `url`. We convert these into `Document` objects so the rest of our pipeline stays identical — the same `format_context()` and `ask_rag()` functions work unchanged.

# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_core.documents import Document

# Create the web search tool
# max_results: how many web pages to retrieve per query (3–5 is a good range)
web_search = TavilySearchResults(
    max_results=4,
    tavily_api_key=os.getenv("TAVILY_API_KEY"),
)

def web_search_to_docs(query: str) -> list:
    """
    Run a web search and convert results to Document objects
    so they work with our existing format_context() function.
    Each Document gets:
      - page_content: the retrieved text snippet
      - metadata["source"]: the URL
      - metadata["page"]: "web" (instead of a page number)
    """
    results = web_search.invoke(query)
    docs = []
    for r in results:
        docs.append(Document(
            page_content=r["content"],
            metadata={"source": r["url"], "page": "web"},
        ))
    return docs

# Test with a query that definitely requires current/live information
web_query = "Latest developments in AI regulation in Singapore 2025"
web_docs  = web_search_to_docs(web_query)

print(f"🌐 Web search: '{web_query}'")
print(f"   Retrieved {len(web_docs)} results\n")
for i, doc in enumerate(web_docs, 1):
    print(f"  [{i}] Source: {doc.metadata['source']}")
    print(f"       {doc.page_content[:200]}")
    print()
# Out:
# C:\Users\chung_3iinfgi\AppData\Local\Temp\ipykernel_16852\542086635.py:6: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   web_search = TavilySearchResults(
# 🌐 Web search: 'Latest developments in AI regulation in Singapore 2025'
#    Retrieved 4 results
#
#   [1] Source: https://regulations.ai/regulations/RAI-SG-NA-SUMMARY-2026
#        Singapore's AI regulatory landscape is dynamic and continuously evolving, with several key future developments anticipated. The Online Safety (Relief and Accountability) Bill (OSRA Bill) is currently
#
#   [2] Source: https://digital.nemko.com/regulations/singapore-ai-regulation
#        ##
#
# ## High-Impact and Generative AI Oversight
#
# Singapore’s regulatory focus in 2025 extends to the governance of high-impact and generative AI systems, emphasizing robust safety testing, accountabil
#
#   [3] Source: https://www.linkedin.com/posts/nicholasker_ai-regulations-in-2025-is-singapore-getting-activity-7310812823066984448-w7Hz
#        AI Regulations in 2025: Is Singapore getting it right? AI is transforming industries at lightning speed, and with that comes a wave of evolving regulations. Hyperight’s latest article lays out six key
#
#   [4] Source: https://www.linkedin.com/pulse/ai-policy-regulations-singapore-comprehensive-report-newmind-ai-xyvtf
#        ### 📌 Recent Legal Regulations (2020–2025)
#
# Singapore’s regulatory approach is technology-agnostic and flexible, leveraging laws like the PDPA, POFMA, and OCHA. It targets AI misuse through provisions

# %% [markdown]
# ### D2 — Guided: Generate an Answer from Web Results
#
# We can now use the same `format_context()` and the same Groq call — just swapping the source of the context from ChromaDB chunks to live web results.

# %%
WEB_SYSTEM_PROMPT = """You are a research assistant answering questions using live web search results.
Answer using ONLY the retrieved web content provided below.
For every fact, cite the source URL in parentheses.
If the information is not in the provided results, say: I could not find that in the retrieved web content.
Do NOT use your own training knowledge."""

def ask_web_rag(question: str, max_results: int = 4) -> str:
    """Full Web-RAG loop: web search → format context → Groq → answer."""
    # Step 1: retrieve from the web
    docs    = web_search_to_docs(question)
    context = format_context(docs)  # reusing the same function from Part A

    # Step 2: build prompt and generate
    prompt = f"""Question: {question}

Retrieved web content:
{context}

Answer using ONLY the retrieved content above. Cite the source URL for every claim."""

    client   = Groq(api_key=os.getenv("GROQ_API_KEY"))
    response = client.chat.completions.create(
        model="llama-3.1-8b-instant",
        messages=[
            {"role": "system", "content": WEB_SYSTEM_PROMPT},
            {"role": "user",   "content": prompt},
        ],
        temperature=0.2,
    )
    return response.choices[0].message.content

# Ask something that requires live, current information
live_question = "What are the latest AI safety regulations announced in 2025?"

print(f"❓ Question: {live_question}")
print()
answer_web = ask_web_rag(live_question)
print("🤖 Answer (grounded in live web results):")
print(answer_web)
# Out:
# ❓ Question: What are the latest AI safety regulations announced in 2025?
#
# 🤖 Answer (grounded in live web results):
# According to the retrieved web content, the latest AI safety regulations announced in 2025 include:
#
# 1. The Raise Act in New York, which imposes new safety, governance, and incident reporting obligations on large AI developers, including stronger safeguards for children. (Source 1: # Global AI Roundup | December 2025: New AI Laws, Safety Rules & What’s Next)
# 2. The European Commission's draft code of practice for marking and labeling AI-generated content, which sets out technical and visible disclosure requirements ahead of enforceability in August 2026. (Source 1: # Global AI Roundup | December 2025: New AI Laws, Safety Rules & What’s Next)
# 3. The EU AI Act, which takes a risk-based approach and prohibits a few unacceptable AI practices outright, imposing escalating obligations on other AI systems based on their risk level. (Source 2: Since January 2024, Chinese authorities have released further refinements)
# 4. China's mandatory labeling rule for AI-generated content, which compels all online services that create or distribute AI-generated content to clearly label such content. (Source 2: Since January 2024, Chinese authorities have released further refinements)
# 5. The Regulation of Artificial Intelligence Bill in Ireland, which aims to shape the national regulatory framework for AI. (Source 3: 14110, on the Safe, Secure, and Trustworthy development and Sse of Artificial Intelligence)
# 6. The Framework Act on the Development of AI and Establishment of a Foundation of Trust in South Korea, which is a comprehensive AI law sharing common elements with the EU AI Act. (Source 4: South Korea enacted the Framework Act on the Development of AI and Establishment of a Foundation of Trust)
# 7. The AI Opportunities Action Plan in the UK, which outlines its commitment to shaping the future of AI and includes enabling safe and trusted AI development and adoption through regulation, safety, and assurance. (Source 4: South Korea enacted the Framework Act on the Development of AI and Establishment of a Foundation of Trust)
#
# Note that the retrieved web content does not provide information on specific AI safety regulations announced in 2025, but rather mentions various developments and initiatives in the field of AI regulation and governance.

# %% [markdown]
# ### D3 — ✏️ YOUR TURN: Compare Local RAG vs Web RAG on the Same Question
#
# Now ask the **same question** to both your local ChromaDB retriever and the web search retriever.
# Choose a question where your local PDF might have partial information but the web would have more current details —
# for example: a topic your PDF covers, but the web has newer developments on.
#
# **Goal:** understand when to use each approach, and when to combine them.

# %%
# ✏️ YOUR TURN: pick a question that makes sense for both your local PDF AND the web
# Good examples:
#   - A topic your PDF covers historically, but the web has 2025 updates on
#   - A regulation your PDF mentions, but whose current status you want to verify
#   - A technology your PDF explains, but recent benchmarks exist online

comparison_question = "What game development software is there?"

# ── Local RAG (your PDF) ──────────────────────────────────────────────────────
# ✏️ YOUR TURN: use ask_rag() with store_800's retriever
store_800, c = build_index(pages, 800, 120, "./chroma_lab_D3")
local_retriever = store_800.as_retriever(search_kwargs={"k": 3})   # YOUR CODE HERE
local_answer, local_docs = ask_rag(comparison_question, local_retriever)  # YOUR CODE HERE

print("=" * 60)
print("📄 LOCAL RAG (from your PDF)")
print("=" * 60)
print("Sources used:", [
    f"page {d.metadata.get('page') + 1}" if isinstance(d.metadata.get('page'), int) else "page ?"
    for d in local_docs
])
print(local_answer)

print()
print("=" * 60)
print("🌐 WEB RAG (live web search)")
print("=" * 60)

# ✏️ YOUR TURN: use ask_web_rag() with the same question
web_answer = ask_web_rag(comparison_question)  # YOUR CODE HERE
print(web_answer)
# Out:
# ============================================================
# 📄 LOCAL RAG (from your PDF)
# ============================================================
# Sources used: ['page 2', 'page 1', 'page 1']
# There are several game development software mentioned in the context:
#
# 1. Unity (page 2, Source 1; page 1, Source 2; page 1, Source 3)
# 2. Unity WebGL (page 2, Source 1)
# 3. Unity Gaming Services (page 2, Source 1; page 1, Source 3)
#
# Additionally, Maya is mentioned as a tool used for modeling 3D structures (page 1, Source 2).
#
# ============================================================
# 🌐 WEB RAG (live web search)
# ============================================================
# **Game Development Software and Tools**
#
# Game development software and tools include game engines, graphics and audio software, and Integrated Development Environments (IDEs) (Source 1).
#
# **Popular Game Development Software**
#
# Professionals use game development software like Unity, GamesDevelop, Open 3D Engine, or JavaScript amongst other scripting languages to code the gameplay logic (Source 1).
#
# **Game Engines**
#
# Unity is a game engine founded in 2004 that helps devs build 3D worlds for games, including character simulations (Source 1). Unreal Engine 5 and Unity 6 are geared for indie devs and studios (Source 2).
#
# **2D and 3D Games**
#
# 2D games: Godot Engine, Unity 6, GameMaker, Construct, and Stencyl (Source 2). 3D games: Unity 6 and Unreal Engine 5 (Source 2).
#
# **Mobile Games**
#
# Mobile games: Unity 6 and Buildbox (Source 2).
#
# **VR/AR Games**
#
# VR/AR games: Unreal Engine 5 and Unity 6 (Source 2).
#
# **Beginner-Friendly Software**
#
# Beginner-friendly software includes GameMaker, Godot, Construct 3, Stencyl, and Buildbox, which offer no-code or drag-and-drop workflows (Source 2).
#
# **Top Game Development and Design Software and Tools**
#
# Unity is a widely adopted game development tool used for creating both 2D and 3D games (Source 3). Unreal Engine is another popular game development tool (Source 3).
#
# **Other Game Development Software and Tools**
#
# Other game development software and tools include:
#
# - Daz Studio (Source 4)
# - Defold (Source 4)
# - DimensioneX Multiplayer Engine (Source 4)
# - Dreams (video game) (Source 4)
# - DX Studio (Source 4)
# - Family BASIC (Source 4)
# - Far-Play (Source 4)
# - Felgo (Source 4)
# - Fighter Maker (Source 4)
# - Figment: The Imagination Processor (Source 4)
# - Adobe Flash (Source 4)
# - FMOD (Source 4)
# - Forgotten Realms: Unlimited Adventures (Source 4)
# - Game Builder Garage (Source 4)
# - Game creation system (Source 4)
# - The Game Creators (Source 4)
# - Game Editor (Source 4)
# - GameSalad (Source 4)
# - Garry Kitchen's GameMaker (Source 4)
# - GDevelop (Source 4)
# - General Graphics Interface (Source 4)
# - GigaMesh Software Framework (Source 4)
# - GLBasic (Source 4)
# - Glide (API) (Source 4)
# - Gmax (Source 4)
# - Godot (game engine) (Source 4)
# - Graphic Adventure Creator (Source 4)
# - Havok (software) (Source 4)
# - Hollywood (programming language) (Source 4)
# - Horizon Worlds (Source 4)
# - Inform (Source 4)
# - IRIS GL (Source 4)
# - Kalydo (Source 4)
# - Kodu Game Lab (Source 4)
# - Krotos Ltd (Source 4)
# - Adobe Authorware (Source 4)
# - Adobe Director (Source 4)
# - Adobe Shockwave (Source 4)
# - Adobe Shockwave Player (Source 4)
# - ADRIFT (Source 4)
# - Adventure Construction Set (Source 4)
# - Adventure Game Toolkit (Source 4)
# - Adventure Master (Source 4)
# - AgentCubes (Source 4)
# - AgentSheets (Source 4)
# - Alice (software) (Source 4)
# - Allegro (software library) (Source 4)
# - AMOS (programming language) (Source 4)
# - Arcade Game Construction Kit (Source 4)
# - Audiere (Source 4)
# - Audiokinetic Wwise (Source 4)
# - Autodesk Gameware (Source 4)
# - The Bard's Tale Construction Set (Source 4)
# - BASIC Programming (Source 4)
# - Basic4GL (Source 4)
# - Beats of Rage (Source 4)
# - BennuGD (Source 4)
# - Blitz BASIC (Source 4)
# - Buildbox (Source 4)
# - C4 Engine (Source 4)
# - Catrobat (Source 4)
# - ClanLib (Source 4)
# - Clara.io (Source 4)
# - Clickteam (Source 4)
# - Clickteam Fusion (Source 4)
# - Cocos2d (Source 4)
# - CodeCombat (Source 4)
# - Core (video game) (Source 4)
# - CryEngine (Source 4)
# - LayaBox (Source 4)
# - Leadwerks (Source 4)
# - LibGDX (Source 4)
# - Löve (game framework) (Source 4)
# - LWJGL (Source 4)
# - Managed DirectX (Source 4)
# - MB-Lab (Source 4)
# - MeshLab (Source 4)
# - MeshInspector (Source 4)
# - MeshLib (Source 4)
# - Mightier (Source 4)
# - MonoGame (Source 4)
# - Mugen (game engine) (Source 4)
# - Multimedia Fusion (Source 4)
# - Net Yaroze (Source 4)
# - Nvidia 3D Vision (Source 4)
# - Nvidia GameWorks (Source 4)
# - OE-Cake! (Source 4)
# - Official Hamster Republic Role Playing Game Construction Engine (Source 4)
# - OGRE (Source 4)
# - Open Roberta (Source 4)
# - OpenGL (Source 4)
# - PICO-8 (Source 4)
# - Pie in the Sky (game engine) (Source 4)
# - Pinball Builder (Source 4)
# - Pinball Construction Set (Source 4)
# - Pixel Game Maker MV (Source 4)
# - Platinum Arts Sandbox (Source 4)
# - PlayCanvas (Source 4)
# - Pokémon Essentials (Source 4)
# - ProDG (software) (Source 4)
# - Professional Adventure Writer (Source 4)
# - Pygame (Source 4)
# - The Quill (software) (Source 4)
# - R (Source 4)
#
# Note: The list of game development software and tools is not exhaustive and is based on the retrieved web content.

# %% [markdown]
# ### D4 — 🔬 EXPERIMENT: Combining Both (Hybrid Retrieval)
#
# The most powerful approach is to merge results from both your local index AND the web,
# then let the LLM synthesise across all sources. This is how production systems like Perplexity work.
#
# This cell is **fully written** — just run it and observe how the answer changes when the LLM has both local and web context.

# %%
HYBRID_SYSTEM_PROMPT = """You are a research assistant with access to both a local document library and live web search results.
You will receive context from two sources: LOCAL DOCUMENT and WEB SEARCH.
Synthesise information from both sources to give the most complete and accurate answer.
Clearly label which source each piece of information comes from:
  - Local: cite the page number
  - Web: cite the URL
If the sources contradict each other, note the discrepancy and explain which seems more current."""

def ask_hybrid_rag(question: str, local_retriever, k_web: int = 3) -> str:
    """Retrieves from both local ChromaDB and web, then generates a combined answer."""
    # Get local chunks
    local_docs = local_retriever.invoke(question)
    # Get web results
    web_docs   = web_search_to_docs(question)

    # Format each source separately so the LLM can attribute correctly
    local_context = format_context(local_docs)
    web_context   = format_context(web_docs)

    prompt = f"""Question: {question}

=== LOCAL DOCUMENT CONTEXT ===
{local_context}

=== LIVE WEB SEARCH CONTEXT ===
{web_context}

Synthesise both sources to answer the question. Label each fact with its source (page number or URL)."""

    client   = Groq(api_key=os.getenv("GROQ_API_KEY"))
    response = client.chat.completions.create(
        model="llama-3.1-8b-instant",
        messages=[
            {"role": "system", "content": HYBRID_SYSTEM_PROMPT},
            {"role": "user",   "content": prompt},
        ],
        temperature=0.2,
    )
    return response.choices[0].message.content

# Run with the same question from D3
hybrid_retriever = store_800.as_retriever(search_kwargs={"k": 3})
hybrid_answer    = ask_hybrid_rag(comparison_question, hybrid_retriever)

print("=" * 60)
print("🔀 HYBRID RAG (local PDF + live web)")
print("=" * 60)
print(hybrid_answer)
# Out:
# ============================================================
# 🔀 HYBRID RAG (local PDF + live web)
# ============================================================
# Based on the provided local document and live web search results, here's a comprehensive list of game development software:
#
# **Game Engines:**
#
# 1. Unity (Source 1: page 2, Source 2: URL [https://www.creativebloq.com/game-development/game-development-software-3231541](https://www.creativebloq.com/game-development/game-development-software-3231541), Source 3: URL [https://www.creativebloq.com/game-development/game-development-software-3231541](https://www.creativebloq.com/game-development/game-development-software-3231541))
# 2. Unreal Engine (Source 2: URL [https://www.creativebloq.com/game-development/game-development-software-3231541](https://www.creativebloq.com/game-development/game-development-software-3231541), Source 3: URL [https://www.creativebloq.com/game-development/game-development-software-3231541](https://www.creativebloq.com/game-development/game-development-software-3231541))
# 3. Godot (Source 2: URL [https://www.creativebloq.com/game-development/game-development-software-3231541](https://www.creativebloq.com/game-development/game-development-software-3231541))
# 4. Open 3D Engine (Source 1: page 2)
# 5. GamesDevelop (Source 2: URL [https://www.creativebloq.com/game-development/game-development-software-3231541](https://www.creativebloq.com/game-development/game-development-software-3231541))
# 6. JavaScript (Source 2: URL [https://www.creativebloq.com/game-development/game-development-software-3231541](https://www.creativebloq.com/game-development/game-development-software-3231541))
# 7. CryEngine (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 8. LayaBox (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 9. Leadwerks (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 10. LibGDX (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 11. Löve (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 12. LWJGL (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 13. MonoGame (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 14. Mugen (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 15. Net Yaroze (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 16. Nvidia 3D Vision (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 17. Nvidia GameWorks (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 18. OGRE (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 19. Open Roberta (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 20. OpenGL (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 21. ProDG (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 22. Pygame (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 23. The Quill (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
#
# **Graphics and Audio Software:**
#
# 1. Autodesk Maya (Source 2: URL [https://www.creativebloq.com/game-development/game-development-software-3231541](https://www.creativebloq.com/game-development/game-development-software-3231541))
# 2. Adobe Illustrator (Source 2: URL [https://www.creativebloq.com/game-development/game-development-software-3231541](https://www.creativebloq.com/game-development/game-development-software-3231541))
# 3. Adobe Photoshop (Source 2: URL [https://www.creativebloq.com/game-development/game-development-software-3231541](https://www.creativebloq.com/game-development/game-development-software-3231541))
# 4. 3ds Max (Source 2: URL [https://www.creativebloq.com/game-development/game-development-software-3231541](https://www.creativebloq.com/game-development/game-development-software-3231541))
# 5. DAWs like Audacity (Source 2: URL [https://www.creativebloq.com/game-development/game-development-software-3231541](https://www.creativebloq.com/game-development/game-development-software-3231541))
# 6. Wwise (Source 2: URL [https://www.creativebloq.com/game-development/game-development-software-3231541](https://www.creativebloq.com/game-development/game-development-software-3231541))
# 7. FMOD (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 8. Adobe Flash (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
#
# **Integrated Development Environments (IDEs):**
#
# 1. Unity's editor (Source 1: page 2, Source 2: URL [https://www.creativebloq.com/game-development/game-development-software-3231541](https://www.creativebloq.com/game-development/game-development-software-3231541))
# 2. Unreal Engine's editor (Source 2: URL [https://www.creativebloq.com/game-development/game-development-software-3231541](https://www.creativebloq.com/game-development/game-development-software-3231541))
# 3. Godot's editor (Source 2: URL [https://www.creativebloq.com/game-development/game-development-software-3231541](https://www.creativebloq.com/game-development/game-development-software-3231541))
# 4. Visual Studio (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 5. CodeCombat (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 6. Allegro (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 7. AMOS (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 8. Blitz BASIC (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 9. Basic4GL (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 10. BennuGD (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 11. Catrobat (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 12. ClanLib (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 13. Clara.io (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 14. Clickteam (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 15. Clickteam Fusion (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 16. Cocos2d (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 17. Core (Source 4: URL [https://en.wikipedia.org/wiki/List_of_game_engines](https://en.wikipedia.org/wiki/List_of_game_engines))
# 18. C4 Engine (Source 4: URL [https://en.wikipedia.org/wiki

# %% [markdown]
# ### 📝 Reflection D
#
# 1. **Local vs Web:** For your chosen question, which source gave a more complete answer?
#
#    The web gives more complete answer.
#
# 2. **Hybrid answer:** Did combining both sources produce a noticeably better answer than either alone? What did each source contribute?
#
#    Yes both sources produce better answer but most of it comes from the web source.
#
# 3. **When would you choose each approach in a real product?**
#
#    | Scenario | Best approach | Reason |
#    |---|---|---|
#    | Internal HR policy bot | Local RAG | Policy is private, not on the web |
#    | Current news summariser | Web RAG | Need to get latest news online |
#    | Product manual Q&A with recent updates | Both | Need to get previous online data and local recent updates data |
#    | General research assistant | Local RAG | Research data is private, not for web |
#
# 4. **What is one risk** of using web-augmented RAG that doesn't exist with local RAG?
#
#    You cannot verify or control what is being retrieved from the web.

# %% [markdown]
# ---
# ## 🧪 PART E — RAG Evaluation with RAGAS  *(Optional — Stretch Goal)*
#
# > **This section is optional.** Complete Parts A–D first. If you have time remaining, come back here.
#
# ### Why evaluate?
#
# So far you have been evaluating RAG the hard way: reading retrieved chunks and answers manually and forming a gut feeling about quality. That works for a few questions — but in a real product with thousands of queries, you need **automated, reproducible metrics**.
#
# ### What is RAGAS?
#
# **RAGAS** (Retrieval Augmented Generation Assessment) is an open-source Python library that automatically scores your RAG pipeline on four key metrics — using an LLM as a judge. It requires no human-labelled ground truth for the basic metrics.
#
# | Metric | What it asks | Score range |
# |---|---|---|
# | **Faithfulness** | Is every claim in the answer supported by the retrieved context? (no hallucination) | 0–1 (higher = better) |
# | **Answer Relevancy** | Does the answer actually address the user's question? | 0–1 (higher = better) |
# | **Context Recall** | Did retrieval find all the evidence needed to answer? | 0–1 (higher = better) |
# | **Context Precision** | Are the retrieved chunks relevant? Low = noisy retrieval | 0–1 (higher = better) |
#
# We will run **Faithfulness** and **Answer Relevancy** — the two that don't require ground-truth reference answers, making them the easiest to use.
#
# ### E0 — Install RAGAS

# %%
import sys
# !{sys.executable} -m pip install -q ragas datasets
print("✅ RAGAS installed")
# Out:
# ^C
# ✅ RAGAS installed

# %% [markdown]
# ### E1 — Guided: Understand the RAGAS Input Format
#
# RAGAS expects a dataset where each row represents one Q&A exchange and contains:
#
# | Field | Type | Description |
# |---|---|---|
# | `user_input` | `str` | The question that was asked |
# | `response` | `str` | The LLM's answer |
# | `retrieved_contexts` | `list[str]` | The raw text of each retrieved chunk (as plain strings) |
# | `reference` | `str` | *(Optional)* Ground-truth answer — needed for Context Recall but not Faithfulness/Relevancy |
#
# The cell below shows how to build this dataset from your existing `ask_rag()` function.

# %%
# This cell is fully written — run it to see what RAGAS data looks like

# We'll run 3 test questions through our local RAG pipeline
# and collect (question, answer, retrieved_chunks) for each

eval_retriever = store_800.as_retriever(search_kwargs={"k": 4})

# Define a few representative test questions for your document
# 📌 Change these to questions that make sense for YOUR PDF
test_questions = [
    "What are the main topics covered in this document?",
    "What is the current price of Bitcoin?",         # out-of-scope — should score low on faithfulness
    "What does the document say about deadlines?",   # replace with something relevant to your PDF
]

# Collect results
eval_rows = []
for q in test_questions:
    answer, docs = ask_rag(q, eval_retriever)
    eval_rows.append({
        "user_input"          : q,
        "response"            : answer,
        "retrieved_contexts"  : [doc.page_content for doc in docs],  # plain strings, not Document objects
    })
    print(f"✅ Collected: {q[:60]}...")

print(f"\n📊 {len(eval_rows)} rows ready for evaluation")
print()
print("Sample row (first question):")
print(f"  user_input         : {eval_rows[0]['user_input']}")
print(f"  response (first 100): {eval_rows[0]['response'][:100]}...")
print(f"  retrieved_contexts : {len(eval_rows[0]['retrieved_contexts'])} chunks")

# %% [markdown]
# ### E2 — ✏️ YOUR TURN: Run the RAGAS Evaluation
#
# Now you will build the RAGAS dataset and run evaluation. Fill in the three gaps marked `# ✏️ YOUR TURN`.
#
# **What to expect:**
# - The evaluation takes ~30–60 seconds — RAGAS uses an LLM internally to score each answer
# - By default RAGAS uses OpenAI. We configure it to use Groq instead (free)
# - Scores will be between 0 and 1 — higher is better
# - The out-of-scope Bitcoin question should score **low** on faithfulness (the model likely hallucinated)

# %%
from datasets import Dataset
from ragas import evaluate
from ragas.metrics import faithfulness, answer_relevancy
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from langchain_groq import ChatGroq
from langchain_huggingface import HuggingFaceEmbeddings

# ── Configure RAGAS to use Groq + local embeddings (both free) ─────────────────
ragas_llm = LangchainLLMWrapper(ChatGroq(
    model_name="llama-3.1-8b-instant",
    temperature=0,
    groq_api_key=os.getenv("GROQ_API_KEY"),
))
ragas_embeddings = LangchainEmbeddingsWrapper(
    HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
)

# ── ✏️ YOUR TURN 1: Build the Hugging Face Dataset from eval_rows ──────────────
# Hint: Dataset.from_list(eval_rows)
eval_dataset = ___________  # YOUR CODE HERE

print(f"Dataset columns : {eval_dataset.column_names}")
print(f"Dataset rows    : {len(eval_dataset)}")
print()

# ── ✏️ YOUR TURN 2: Run the evaluation ─────────────────────────────────────────
# Hint: evaluate(
#     dataset=eval_dataset,
#     metrics=[faithfulness, answer_relevancy],
#     llm=ragas_llm,
#     embeddings=ragas_embeddings,
# )
print("Running RAGAS evaluation (takes ~30–60 seconds)...")
results = ___________  # YOUR CODE HERE

print("\n✅ Evaluation complete!")
print()

# ── ✏️ YOUR TURN 3: Print the results as a readable table ──────────────────────
# Hint: results.to_pandas() gives you a DataFrame
# Print columns: user_input, faithfulness, answer_relevancy
df = ___________  # YOUR CODE HERE — convert results to a DataFrame

# Print per-question scores
print(f"{'Question':<50}  {'Faithful':>9}  {'Relevant':>9}")
print("-" * 72)
for _, row in df.iterrows():
    q_short  = str(row.get('user_input', ''))[:48]
    faith    = row.get('faithfulness',    float('nan'))
    relevant = row.get('answer_relevancy', float('nan'))
    print(f"{q_short:<50}  {faith:>9.3f}  {relevant:>9.3f}")

# Print average scores
print("-" * 72)
print(f"{'AVERAGE':<50}  {df['faithfulness'].mean():>9.3f}  {df['answer_relevancy'].mean():>9.3f}")

# %% [markdown]
# ### 📝 Reflection E
#
# 1. **Faithfulness score for the out-of-scope question** (Bitcoin price): was it low as expected? What does a low faithfulness score indicate?
#
#    *Your answer:*
#
# 2. **chunk_size=300 vs chunk_size=800:** did the RAGAS scores change? Which metric changed more — faithfulness or relevancy? Why do you think that is?
#
#    *Your answer:*
#
# 3. **Limitation of this evaluation setup:** we are using an LLM (LLaMA via Groq) as both the RAG generator AND the RAGAS judge. What problem could this cause?
#
#    *Your answer:*
#
# 4. **In a production RAG system**, how often would you run RAGAS evaluation — and on how many questions?
#
#    *Your answer:*

# %% [markdown]
# ---
# ## 🧹 Cleanup
#
# Run this cell when you are done to remove all temporary ChromaDB index folders.

# %%
dirs_to_clean = [
    "./chroma_lab_notebook",
    "./chroma_exp_300",
    "./chroma_exp_800",
    "./chroma_exp_1500",
    "./chroma_k_exp",
]
for d in dirs_to_clean:
    if Path(d).exists():
        shutil.rmtree(d)
        print(f"🗑  Removed {d}")
print("✅ Cleanup done")
